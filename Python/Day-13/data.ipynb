# %%
import pandas as pd
data={
    'name':['alice','bob','carlo'],
    'age':[21,34,32],
    'city':['hyderabad','los angles','ameerpet']
}


df=pd.DataFrame(data)
df.sort_values(by='age',ascending=False)
# Out:
#     name  age        city
# 1    bob   34  los angles
# 2  carlo   32    ameerpet
# 0  alice   21   hyderabad

# %%
df2=pd.read_csv("customers-100.csv")

# %%
json1=df2.to_json()
with open("customers-100.json",'w') as file:
    file.write(json1)

# %%
print(df2.head(3))
# Out:
#    Index      Customer Id First Name Last Name          Company  \
# 0      1  DD37Cf93aecA6Dc     Sheryl    Baxter  Rasmussen Group
# 1      2  1Ef7b82A4CAAD10    Preston    Lozano      Vega-Gentry
# 2      3  6F94879bDAfE5a6        Roy     Berry    Murillo-Perry
#
#                 City              Country          Phone 1  \
# 0       East Leonard                Chile     229.077.5154
# 1  East Jimmychester             Djibouti       5153435776
# 2      Isabelborough  Antigua and Barbuda  +1-539-402-0259
#
#                Phone 2                     Email Subscription Date  \
# 0     397.884.0519x718  zunigavanessa@smith.info        2020-08-24
# 1     686-620-1820x944           vmata@colon.com        2021-04-23
# 2  (496)978-3969x58947       beckycarr@hogan.com        2020-03-25
#
#                       Website
# 0  http://www.stephenson.com/
# 1       http://www.hobbs.com/
# 2    http://www.lawrence.com/

# %%
df2.set_index(['First Name','Company','Country'],inplace=True)

# %%
print(df2)
# Out:
#                                                                        Index  \
# First Name Company                         Country
# Sheryl     Rasmussen Group                 Chile                           1
# Preston    Vega-Gentry                     Djibouti                        2
# Roy        Murillo-Perry                   Antigua and Barbuda             3
# Linda      Dominguez, Mcmillan and Donovan Dominican Republic              4
# Joanna     Martin, Lang and Andrade        Slovakia (Slovak Republic)      5
# ...                                                                      ...
# Karl       Carey LLC                       Guyana                         96
# Lynn       Ware, Burns and Oneal           Sri Lanka                      97
# Fred       Schmitt-Jones                   Solomon Islands                98
# Yvonne     Fitzgerald-Harrell              Aruba                          99
# ...
